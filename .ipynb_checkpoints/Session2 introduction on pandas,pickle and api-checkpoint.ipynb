# %%
test = 'Germany (not BRY)'

print(test.split('(')[0].strip())#strip removes the spaces
# Out:
# Germany

# %% [markdown]
# ## first example: economics automation

# %% [markdown]
# ### pandas is a library to manipulate data

# %%
import pandas as pd

# %%
import time

# %%
import random

# %%
import pickle

# %%
filename='/home/pier/Documents/P19/US02/Data-sheet-STUDENTS.xlsx'

# %% [markdown]
# ### let's take a look at the excel file

# %%
df = pd.read_excel(filename,header=2,usecols='B:AR')

# %%
df
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 0                          Afghanistan                      NaT
# 1                              Albania                      NaT
# 2                              Armenia                      NaT
# 3                           Azerbaijan                      NaT
# 4                              Bahrain                      NaT
# 5                           Bangladesh                      NaT
# 6                              Belarus                      NaT
# 7                               Bhutan                      NaT
# 8               Bosnia and Herzegovina                      NaT
# 9                               Brunei                      NaT
# 10                            Bulgaria                      NaT
# 11                            Cambodia               2018-08-16
# 12                               China                      NaT
# 13                             Croatia                      NaT
# ...

# %%
df['Country (according to CN Gov):']
# Out:
# 0                            Afghanistan
# 1                                Albania
# 2                                Armenia
# 3                             Azerbaijan
# 4                                Bahrain
# 5                             Bangladesh
# 6                                Belarus
# 7                                 Bhutan
# 8                 Bosnia and Herzegovina
# 9                                 Brunei
# 10                              Bulgaria
# 11                              Cambodia
# 12                                 China
# 13                               Croatia
# 14                        Czech Republic
# 15                            East Timor
# 16                                 Egypt
# 17                               Estonia
# 18                      France (Not BRI)
# 19                               Georgia
# 20                     Germany (not BRI)
# 21                               Hungary
# 22                                 India
# ...

# %%
for index,country in df['Country (according to CN Gov):'].iteritems():
    country=country.split('(')[0].strip()
    print(country)
# Out:
# Afghanistan
# Albania
# Armenia
# Azerbaijan
# Bahrain
# Bangladesh
# Belarus
# Bhutan
# Bosnia and Herzegovina
# Brunei
# Bulgaria
# Cambodia
# China
# Croatia
# Czech Republic
# East Timor
# Egypt
# Estonia
# France
# Georgia
# Germany
# Hungary
# India
# Indonesia
# Iran
# Iraq
# Israel
# Jordan
# Kazakhstan
# Kuwait
# Kyrgyzstan
# Laos
# Latvia
# Lebanon
# Lithuania
# Macedonia
# Malaysia
# Maldives
# Moldova
# Mongolia
# Montenegro
# Myanmar
# Nepal
# Oman
# Pakistan
# Philippines
# Poland
# Qatar
# Romania
# Russia
# Saudi Arabia
# Serbia
# Singapore
# Slovakia
# Slovenia
# Sri Lanka
# Syria
# Tajikistan
# Thailiand
# The United Arab Emirates
# Turkey
# Turkmenistan
# United Kingdom
# United States of America
# Ukraine
# Uzbekistan
# Vietnam
# Yemen

# %% [markdown]
# ## request an api on worldbank

# %%
import requests

# %%
url = 'http://api.worldbank.org/v2/Country/CHN/indicator/GC.TAX.IMPT.ZS?format=json'
r=requests.get(url)
print(r.status_code)
data=r.json()
print('data for',data[1][1]['country']['value'],'is',data[1][1]['value'])
# Out:
# 200
# data for China is None

# %%
for i in data[1]:
    if i['value'] is None:
        continue
    else:
        print(i['value'])
        break
# Out:
# 3.89434134127694

# %% [markdown]
# ### to get the first value of http://api.worldbank.org/v2/Country/'+country_alpha3Code+'/indicator/GC.TAX.IMPT.ZS?format=json from the code of a country

# %%
def first_value_GC(country_alpha3Code='FRA'):
    r=requests.get('http://api.worldbank.org/v2/Country/'+country_alpha3Code+'/indicator/GC.TAX.IMPT.ZS?format=json')
    data=r.json()
    for i in data[1]:
        if i['value'] is None:
            continue
        else:
            print(i['value'])
            break
first_value_GC()
# Out:
# -0.0219075038047324

# %%
country_name = 'France'
url = 'https://restcountries.eu/rest/v2/name/' + country_name
r = requests.get(url)
data = r.json()
print(country_name, data[0]['alpha3Code'])
# Out:
# France FRA

# %%
def get_iso_code(country_name):
    url = 'https://restcountries.eu/rest/v2/name/' + country_name
    try:
        r = requests.get(url)
        data = r.json()
        #print(data[0]['alpha3Code'])
        return(data[0]['alpha3Code'])
    except KeyError:
        print('[ERROR] cannot get code for',country_name)
        return None

# %% [markdown]
# ### very long to search in the api

# %%
print(country_to_alpha3Code('France'))

# %% [markdown]
# ### let's build the list of the alpha3codes from countries

# %%
alpha3Codes=[]
for c in df['Country (according to CN Gov):']:
    print(c.split('(')[0].strip())
    c=c.split('(')[0].strip()
    print(alpha3Codes)
    alpha3Codes.append(country_to_alpha3Code(c))

# %% [markdown]
# ### declare the dictionnary in an other cell to be more flexible with others
# make sure you can start after a crash without losing the data. And save the errors. Try to continue after error

# %%
countries = {}

# %%
for i,v in df['Country (according to CN Gov):'].iteritems():
    country_name = v.split('(')[0].strip()
    if country_name not in countries.keys():
        iso_code = get_iso_code(country_name)
        if iso_code is not None:
            countries[country_name] = iso_code
            print(country_name,iso_code)
            time.sleep(0.5+random.random())
# Out:
# Afghanistan AFG
# Albania ALB
# Armenia ARM
# Azerbaijan AZE
# Bahrain BHR
# Bangladesh BGD
# Belarus BLR
# Bhutan BTN
# Bosnia and Herzegovina BIH
# Brunei BRN
# Bulgaria BGR
# Cambodia KHM
# China CHN
# Croatia HRV
# Czech Republic CZE
# East Timor TLS
# Egypt EGY
# Estonia EST
# France FRA
# Georgia GEO
# Germany DEU
# Hungary HUN
# India IOT
# Indonesia IDN
# Iran IRN
# Iraq IRQ
# Israel ISR
# Jordan JOR
# Kazakhstan KAZ
# Kuwait KWT
# Kyrgyzstan KGZ
# Laos LAO
# Latvia LVA
# Lebanon LBN

# %%
countries['Thailiand'] = 'THA'
countries['The United Arab Emirates'] = 'ARE'

# %%
len(countries.keys()) == len(df['Country (according to CN Gov):'])b

# %% [markdown]
# ## we can save the dictionary with pickle to use it in a different file

# %%
with open ('counties.pickle','wb+') as fp:
    pickle.dump(countries, fp)

# %%
with open ('countries.pickle','rb') as fp:
    test = pieckle.load(fp)
test

# %%
import tqdm

# %%
url = 'http://api.worldbank.org/v2/country/CHN/indicator/GC.TAX.IMPT.ZS?format=json'
r = requests.get(url)
print(r.status_code)
data = r.json()
print('data for',data[1][1]['country']['value'],'is',data[1][1]['value'])
print(data[1][1])

# %%
for i in data[1]:
    if i['value'] is None:
        continue
    else:
        print(i['date'],i['value'])
        break

# %%
country_name = 'France'
url = 'https://restcountries.eu/rest/v2/name/' + country_name
r = requests.get(url)
data = r.json()
print(country_name, data[0]['alpha3Code'])
